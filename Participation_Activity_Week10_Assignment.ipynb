# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pushd "/content/drive/MyDrive/MSSP607/Modules/Week_10"
# Out:
# /content/drive/MyDrive/MSSP607/Modules/Week_10
# ['/content']

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams.update({
    'figure.figsize': (7.5, 7.5),
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False})

# %%
import networkx as nx
G2 = nx.Graph()

G2.add_nodes_from(['Zhu','Dai','Lin','Jiang','Li'])
G2.add_edges_from([('Zhu', 'Dai'), ('Lin', 'Jiang'),('Dai','Li'),('Zhu','Jiang'),('Lin','Li'),('Jiang','Li'),('Zhu','Lin')])

plt.figure(figsize=(7.5, 7.5))
nx.draw_networkx(G2)
